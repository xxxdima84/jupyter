# %%
cars = 100 # переменная cars = 100
space_in_a_car = 4.0 # имеем 4 месста в авто
drivers = 30 # у нас 30 водителей
passengers = 90 # количество пассажиров = 90
cars_not_driven = cars-drivers # авто без водителей = авто - водители
cars_driven = drivers # авто с водителями = количеству водителей
carpool_capacity = cars_driven * space_in_a_car # вместимость автобазы = количество авто с водителями * мест в машине
average_passengers_per_car = passengers / cars_driven  # среднее количество пассажиров на машину= количество пасажиров / количество водителей


print("В наличии", cars, "автомобилей.")
print("И только", drivers, "водителей вышли на работу")
print("Получается, что", cars_not_driven, "машин пустуют")
print("Мы можем перевести сегодня", carpool_capacity, "человек.")
print("Сегодня нужно отвести", passengers, "человек.")
print("В каждой машине будет примерно", average_passengers_per_car,"человека")
# Out:
# В наличии 100 автомобилей.
# И только 30 водителей вышли на работу
# Получается, что 70 машин пустуют
# Мы можем перевести сегодня 120.0 человек.
# Сегодня нужно отвести 90 человек.
# В каждой машине будет примерно 3.0 человека

# %%
a = 100 # переменная cars = 100
b = 4 # имеем 4 месста в авто
c = 30 # у нас 30 водителей
d = 90 # количество пассажиров = 90
e= a-c # авто без водителей = авто - водители
j = c # авто с водителями = количеству водителей
z = j * b # вместимость автобазы = количество авто с водителями * мест в машине
r = d / j  # среднее количество пассажиров на машину= количество пасажиров / количество водителей


print("В наличии", a, "автомобилей.")
print("И только", c, "водителей вышли на работу")
print("Получается, что", e, "машин пустуют")
print("Мы можем перевести сегодня", z, "человек.")
print("Сегодня нужно отвести", d, "человек.")
print("В каждой машине будет примерно", r,"человека")
# Out:
# В наличии 100 автомобилей.
# И только 30 водителей вышли на работу
# Получается, что 70 машин пустуют
# Мы можем перевести сегодня 120 человек.
# Сегодня нужно отвести 90 человек.
# В каждой машине будет примерно 3.0 человека
